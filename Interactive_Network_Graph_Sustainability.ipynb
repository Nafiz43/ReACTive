# %% [markdown]
# PyVis is used to generate the network graphs
# [PyVis](https://pyvis.readthedocs.io/en/latest/tutorial.html)
#
# PlotLy Group Function is used to generate the distribution graphs
# [Plotly](https://plotly.com/python/group-by/)
#
#
# Some Acronyms:
# IG: Interactive Graph
# SP: Scatter Plot

# %%
# !pip install pyvis==0.3.1
# !pip install plotly
from pyvis.network import Network
import pandas as pd
from pandas import DataFrame
import plotly.express as px
import textwrap

def extract_numbers(input_string):
    numbers_only = ''.join(char for char in input_string if char.isdigit())
    result_integer = int(numbers_only)
    return result_integer

def wrap_text(text, width=50):
    wrapper = textwrap.TextWrapper(width=width, break_long_words=False)
    return '\n'.join(wrapper.wrap(text))

def wrap_text_withBR(text, width=40):
    wrapper = textwrap.TextWrapper(width=width, break_long_words=False)
    return '<br>'.join(wrapper.wrap(text))

# def CenteredAlign(text, width=50):
#     wrapper = textwrap.TextWrapper(width=width, break_long_words=False)
#     return '<br>'.join(wrapper.wrap(text))
def processing(df):
  for column in df.columns:
    df[column] = df[column].str.lstrip().str.rstrip()
    return df

MainSheet = pd.read_excel("dt.xlsx", sheet_name='main', skiprows=0)
FeatureDescriptionSheet = pd.read_excel("dt.xlsx", sheet_name='FeatureDescription', skiprows=0)
ClassDescriptionSheet = pd.read_excel("dt.xlsx", sheet_name='ClassDescription', skiprows=0)
EntityDescriptionSheet = pd.read_excel("dt.xlsx", sheet_name='EntityDescription', skiprows=0)

# MainSheet = MainSheet.drop(columns=['Article Title', 'Link', 'SL'])

MainSheet = processing(MainSheet)
FeatureDescriptionSheet = processing(FeatureDescriptionSheet)
ClassDescriptionSheet = processing(ClassDescriptionSheet)
EntityDescriptionSheet = processing(EntityDescriptionSheet)
# Display the modified DataFrame
MainSheet['ReACT_title'] = MainSheet['ReACT_title'].apply(wrap_text)

ReAct_Dict = dict(zip(MainSheet['ReACT_number'], MainSheet['ReACT_title']))
FeatureDescription_Dict = dict(zip(FeatureDescriptionSheet['FeatureName'], FeatureDescriptionSheet['DescriptionOfTheFeature']))
ClassDescription_Dict = dict(zip(ClassDescriptionSheet['Class'], ClassDescriptionSheet['ClassDescription']))
EntityDescription_Dict = dict(zip(EntityDescriptionSheet['Entity'], EntityDescriptionSheet['EntityDescription']))
ReActAndTitle = MainSheet[['ReACT_number', 'ReACT_title']]
MainSheet.head()
# Out:
# Requirement already satisfied: pyvis==0.3.1 in /usr/local/lib/python3.10/dist-packages (0.3.1)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis==0.3.1) (3.1.3)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis==0.3.1) (3.2.1)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis==0.3.1) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis==0.3.1) (3.0.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis==0.3.1) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis==0.3.1) (2.1.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis==0.3.1) (0.2.13)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)
#   ReACT_number   Unnamed: 1  \
# 0      ReACT-1  not minable
# 1     ReACT-10          NaN
# 2     ReACT-11          NaN
# 3     ReACT-11          NaN
# 4     ReACT-11          NaN
#
#                                          ReACT_title               Class  \
# 0  Ensure a team of friendly and supportive\ndeve...   Individual, Group
# 1                 Offer job support to the newcomer.          Foundation
# 2                 Keep the project small and simple.  Project, Ecosystem
# 3                 Keep the project small and simple.  Project, Ecosystem
# 4                 Keep the project small and simple.  Project, Ecosystem
#
#                      Entity_responsible                  Features  \
# 0  Project Maintainers, Project Leaders               num_act_dev
# 1              Project Managers, Owners  num_act_dev, c_long_tail
# 2                       Core Developers               num_act_dev
# 3                       Core Developers               num_commits
# 4                       Core Developers      top_c_fract, c_nodes
#
#    Quatative/Qualatitative             References  \
# 0                      NaN  No. of reference: 3\n
# 1                      NaN    No. of reference: 1
# 2                      NaN  No. of reference: 3\n
# 3                      NaN    No. of reference: 1
# 4                      NaN    No. of reference: 1
#
#                                             Articles
# 0  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 1  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 2  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 3  1. Carsten Kolassa, Dirk Riehle, and Michel A....
# 4  1. Jailton Coelho, Marco Tulio Valente, Lucian...

# %% [markdown]
# #Plotting ReAct and Class - Network Diagram

# %%
ReActAndClass = MainSheet[['ReACT_number', 'Class']]

b = DataFrame(ReActAndClass.Class.str.split(',').tolist(), index=ReActAndClass.ReACT_number).stack()
b = b.reset_index()[[0, 'ReACT_number']]
b.columns = ['Class', 'ReACT_number'] # renaming var1
ReActAndClass = b
ReActAndClass = processing(ReActAndClass)


ReActTitleClass = pd.merge(ReActAndTitle, ReActAndClass, on='ReACT_number', how='outer')
ReActTitleClass['ClassDescription'] = None

ReActClassDescription = ReActTitleClass
ReActClassDescription
for i in range(0,len(ReActClassDescription)):
  # print(ReActClassDescription.Class[i].lstrip().rstrip())
  # print(i, ClassDescription_Dict[ReActClassDescription.Class[i].lstrip().rstrip()])
  ReActClassDescription.ClassDescription[i] = ClassDescription_Dict[ReActClassDescription.Class[i].lstrip().rstrip()]
ReAct_Title_Class_ClassDescription = ReActClassDescription

#The following line is added to remove the exact duplicate rows based on ['ReACT_number', 'Class']
ReAct_Title_Class_ClassDescription = ReAct_Title_Class_ClassDescription.drop_duplicates(subset=['ReACT_number', 'Class'])
ReAct_Title_Class_ClassDescription.reset_index(inplace=True, drop=True)
ReAct_Title_Class_ClassDescription
# Out:
#     ReACT_number                                        ReACT_title  \
# 0        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 1        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 2       ReACT-10                 Offer job support to the newcomer.
# 3       ReACT-11                 Keep the project small and simple.
# 4       ReACT-11                 Keep the project small and simple.
# ..           ...                                                ...
# 110     ReACT-88  Assign an experienced team member to coach and...
# 111     ReACT-89  Grant the newcomer freedom: Encourage and allo...
# 112     ReACT-89  Grant the newcomer freedom: Encourage and allo...
# 113      ReACT-9      Grant newcomer access to the main repository.
# 114     ReACT-90  Establish a personalized integration plan: Out...
#
#           Class                                   ClassDescription
# 0    Individual  The Individual class emphasizes the role of in...
# 1         Group  Activities that can be performed by working gr...
# 2    Foundation  Actionable in this class related to financial ...
# 3       Project  The Project class focuses on the overall manag...
# 4     Ecosystem  Actionable in this class related to the projec...
# ..          ...                                                ...
# 110    Pairwise  The pair programming or code reviews, where tw...
# 111  Individual  The Individual class emphasizes the role of in...
# 112       Group  Activities that can be performed by working gr...
# 113        Code  The Code class is centered around the quality ...
# 114     Project  The Project class focuses on the overall manag...
#
# [115 rows x 4 columns]

# %%
ReACT_number = ReAct_Title_Class_ClassDescription['ReACT_number'].values
ReACT_Title = ReAct_Title_Class_ClassDescription['ReACT_title'].values
ReAct_Title_Class_ClassDescription['ReACT_title'] = ReAct_Title_Class_ClassDescription['ReACT_title'].apply(wrap_text)

Class = ReAct_Title_Class_ClassDescription['Class'].values
ReAct_Title_Class_ClassDescription['ClassDescription'] =  ReAct_Title_Class_ClassDescription['ClassDescription'].apply(wrap_text)
ClassDescription = ReAct_Title_Class_ClassDescription['ClassDescription'].values

net = Network(directed =True)
for i in range(0,len(ReACT_number)):
  # print(actionable[i])
  net.add_node(ReACT_number[i], label=ReACT_number[i], title=ReACT_Title[i])
  net.add_node(Class[i], label=Class[i], title=ClassDescription[i], color = "#5DBB63",shape='box')
  net.add_edge(ReACT_number[i], Class[i], color = "#016064")

# net.show_buttons(filter_=['physics'])
net.show('IG_Class.html')
# Out:
# <ipython-input-41-20e73472e94a>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-41-20e73472e94a>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##BarPlot

# %%
unique_counts = ReAct_Title_Class_ClassDescription['Class'].value_counts().reset_index()

# Rename the columns for clarity
unique_counts.columns = ['Class of ReACTs', 'Count of ReACTs']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8', '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65', '#548569', '#474466', '#FDEBD0', '#F9EBB2', '#EAECEE', '#8B5A80']

fig = px.bar(unique_counts, x='Class of ReACTs', y='Count of ReACTs', color='Class of ReACTs', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('BarPlot_Class.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c7285d7-5b60-49d8-a1d3-d141f8b4b3b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c7285d7-5b60-49d8-a1d3-d141f8b4b3b4")) {                    Plotly.newPlot(                        "5c7285d7-5b60-49d8-a1d3-d141f8b4b3b4",                        [{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Code","marker":{"color":"darkred","pattern":{"shape":""}},"name":"Code","offsetgroup":"Code","orientation":"v","showlegend":true,"textposition":"auto","x":["Code"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Individual","marker":{"color":"lightblue","pattern":{"shape":""}},"name":"Individual","offsetgroup":"Individual","orientation":"v","showlegend":true,"textposition":"auto","x":["Individual"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Group","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"Group","offsetgroup":"Group","orientation":"v","showlegend":true,"textposition":"auto","x":["Group"],"xaxis":"x","y":[19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Project","marker":{"color":"#FFABAB","pattern":{"shape":""}},"name":"Project","offsetgroup":"Project","orientation":"v","showlegend":true,"textposition":"auto","x":["Project"],"xaxis":"x","y":[16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Infrastructure","marker":{"color":"#91a8a8","pattern":{"shape":""}},"name":"Infrastructure","offsetgroup":"Infrastructure","orientation":"v","showlegend":true,"textposition":"auto","x":["Infrastructure"],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pairwise","marker":{"color":"#95ab8a","pattern":{"shape":""}},"name":"Pairwise","offsetgroup":"Pairwise","orientation":"v","showlegend":true,"textposition":"auto","x":["Pairwise"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Foundation","marker":{"color":"#00a86b","pattern":{"shape":""}},"name":"Foundation","offsetgroup":"Foundation","orientation":"v","showlegend":true,"textposition":"auto","x":["Foundation"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Class of ReACTs=%{x}\u003cbr\u003eCount of ReACTs=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecosystem","marker":{"color":"#8E44AD","pattern":{"shape":""}},"name":"Ecosystem","offsetgroup":"Ecosystem","orientation":"v","showlegend":true,"textposition":"auto","x":["Ecosystem"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a ...

# %%
import plotly.graph_objects as go
import plotly.io as pio

subject = ReAct_Title_Class_ClassDescription['Class']
score = ReAct_Title_Class_ClassDescription['ReACT_number']

TextToShow = "<b>"+ReAct_Title_Class_ClassDescription['ReACT_number'] + " Belongs to </b>"
TextToShow += "<b>"+ReAct_Title_Class_ClassDescription['Class'] +"</b> Class"+ "<br>"
TextToShow += "<b>"+ReAct_Title_Class_ClassDescription['ReACT_number']+"</b>: "
TextToShow += ReAct_Title_Class_ClassDescription['ReACT_title'].apply(wrap_text_withBR)
TextToShow += "<br><b>" +ReAct_Title_Class_ClassDescription['Class'] +": </b>"
TextToShow += ReAct_Title_Class_ClassDescription['ClassDescription'].apply(wrap_text_withBR)


data = [dict(
  type = 'scatter',
  x = subject,
  y = score,
  mode = 'markers',
  text = TextToShow,  # Set the 'text' property to the Y-axis values
  transforms = [dict(
    type = 'groupby',
    groups = subject
  )],
   marker=dict(
        symbol='square',  # Set the shape of the marker (e.g., 'circle', 'square', 'diamond', etc.)
        size=10  # Set the size of the circles (adjust as needed)

    )
)]

layout = dict(xaxis=dict(title='Features'),
              yaxis=dict(title='ReACT Number'),
              height=1200,
              width=800)

fig_dict = dict(data=data, layout=layout)
pio.show(fig_dict, validate=False)
pio.write_html(fig_dict, file='SP_Class.html', auto_open=True, validate=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9e04bf5-44c0-4899-a0f5-eabca9aca89f" class="plotly-graph-div" style="height:1200px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9e04bf5-44c0-4899-a0f5-eabca9aca89f")) {                    Plotly.newPlot(                        "d9e04bf5-44c0-4899-a0f5-eabca9aca89f",                        [{"type":"scatter","x":["Individual","Group","Foundation","Project","Ecosystem","Foundation","Foundation","Code","Code","Code","Pairwise","Individual","Pairwise","Group","Individual","Individual","Group","Individual","Group","Project","Ecosystem","Individual","Individual","Individual","Project","Group","Code","Code","Pairwise","Group","Code","Infrastructure","Code","Code","Individual","Project","Individual","Project","Pairwise","Project","Individual","Foundation","Code","Infrastructure","Infrastructure","Infrastructure","Individual","Infrastructure","Code","Infrastructure","Infrastructure","Infrastructure","Individual","Pairwise","Group","Project","Group","Code","Project","Individual","Project","Infrastructure","Foundation","Group","Code","Group","Individual","Group","Pairwise","Individual","Group","Code","Ecosystem","Project","Code","Individual","Code","Code","Infrastructure","Code","Project","Group","Project","Group","Code","Code","Code","Code","Code","Code","Code","Project","Individual","Group","Code","Ecosystem","Project","Individual","Code","Project","Infrastructure","Foundation","Individual","Group","Individual","Group","Pairwise","Group","Individual","Individual","Pairwise","Individual","Group","Code","Project"],"y":["ReACT-1","ReACT-1","ReACT-10","ReACT-11","ReACT-11","ReACT-12","ReACT-13","ReACT-14","ReACT-15","ReACT-16","ReACT-17","ReACT-18","ReACT-18","ReACT-18","ReACT-19","ReACT-2","ReACT-2","ReACT-20","ReACT-20","ReACT-20","ReACT-20","ReACT-21","ReACT-22","ReACT-23","ReACT-24","ReACT-25","ReACT-26","ReACT-28","ReACT-29","ReACT-29","ReACT-3","ReACT-30","ReACT-31","ReACT-32","ReACT-33","ReACT-34","ReACT-35","ReACT-36","ReACT-37","ReACT-37","ReACT-38","ReACT-39","ReACT-4","ReACT-40","ReACT-41","ReACT-42","ReACT-42","ReACT-43","ReACT-43","ReACT-44","ReACT-45","ReACT-46","ReACT-46","ReACT-47","ReACT-48","ReACT-48","ReACT-49","ReACT-5","ReACT-50","ReACT-50","ReACT-51","ReACT-52","ReACT-53","ReACT-54","ReACT-55","ReACT-56","ReACT-57","ReACT-57","ReACT-58","ReACT-59","ReACT-59","ReACT-6","ReACT-60","ReACT-60","ReACT-61","ReACT-62","ReACT-63","ReACT-64","ReACT-65","ReACT-66","ReACT-67","ReACT-67","ReACT-68","ReACT-68","ReACT-69","ReACT-7","ReACT-70","ReACT-71","ReACT-72","ReACT-73","ReACT-74","ReACT-75","ReACT-75","ReACT-75","ReACT-76","ReACT-77","ReACT-79","ReACT-79","ReACT-8","ReACT-80","ReACT-81","ReACT-82","ReACT-83","ReACT-83","ReACT-84","ReACT-84","ReACT-85","ReACT-85","ReACT-86","ReACT-87","ReACT-88","ReACT-89","ReACT-89","ReACT-9","ReACT-90"],"mode":"markers","text":["\u003cb\u003eReACT-1 Belongs to \u003c\u002fb\u003e\u003cb\u003eIndividual\u003c\u002fb\u003e Class\u003cbr\u003e\u003cb\u003eReACT-1\u003c\u002fb\u003e: Ensure a team of friendly and supportive\u003cbr\u003edevelopers.\u003cbr\u003e\u003cb\u003eIndividual: \u003c\u002fb\u003eThe Individual class emphasizes the role\u003cbr\u003eof individual Contributors in the\u003cbr\u003esustainability of an open-source\u003cbr\u003eproject. It involves contributing code,\u003cbr\u003ereporting bugs, updating documentation,\u003cbr\u003eand engaging in community discussions.","\u003cb\u003eReACT-1 Belongs to \u003c\u002fb\u003e\u003cb\u003eGroup\u003c\u002fb\u003e Class\u003cbr\u003e\u003cb\u003eReACT-1\u003c\u002fb\u003e: Ensure a team of friendly and supportive\u003cbr\u003edevelopers.\u003cbr\u003e\u003cb\u003eGroup: \u003c\u002fb\u003eActivities that can be performed by\u003cbr\u003eworking groups within t ...

# %% [markdown]
# #Plotting ReAct and Entity - Network Diagram

# %%
ReActAndEntity = MainSheet[['ReACT_number', 'Entity_responsible']]

b = DataFrame(ReActAndEntity.Entity_responsible.str.split(',').tolist(), index=ReActAndEntity.ReACT_number).stack()
b = b.reset_index()[[0, 'ReACT_number']]
b.columns = ['Entity', 'ReACT_number'] # renaming var1
ReActAndEntity = b
ReActAndEntity = processing(ReActAndEntity) # performing lstrip rstrip after the separation
# ReActAndEntity.Entity.value_counts()

# %% [markdown]
# ###Unique values in the Entity Column
# (You neeed description for each item in the EntityDescription Sheet)
# I wrote this to determine the unique values available in the Entity Column. So that, later, I can define each of them in the EntityDescription sheet

# %%
unique_values = set(ReActAndEntity.Entity)

# Convert the unique values back to a list if needed
unique_values_list = list(unique_values)

print(unique_values_list)
for i in range(0,len(unique_values_list)):
  print(unique_values_list[i].lstrip().rstrip())
# Out:
# ['Project Maintainers', 'Project Leaders', 'Project Managers', 'Community Moderators', 'Community Managers', 'Contributors', 'Collaboration Coordinators', 'Owners', 'Developers', 'Design Team', 'Code Reviewers', 'Core Developers', 'Technical Leads', 'Quality Assurance Team', 'Architects', 'Documentation Team', 'Mentors', 'Sponsors']
# Project Maintainers
# Project Leaders
# Project Managers
# Community Moderators
# Community Managers
# Contributors
# Collaboration Coordinators
# Owners
# Developers
# Design Team
# Code Reviewers
# Core Developers
# Technical Leads
# Quality Assurance Team
# Architects
# Documentation Team
# Mentors
# Sponsors

# %%
ReActTitleEntity = pd.merge(ReActAndTitle, ReActAndEntity, on='ReACT_number', how='outer')
ReActTitleEntity['EntityDescription'] = None

ReActEntityDescription = ReActTitleEntity

for i in range(0,len(ReActEntityDescription)):
  ReActEntityDescription.EntityDescription[i] = EntityDescription_Dict[ReActEntityDescription.Entity[i].lstrip().rstrip()]
ReAct_Title_Entity_EntityDescription = ReActEntityDescription

#The following line is added to remove the exact duplicate rows based on ['ReACT_number', 'Entity']
ReAct_Title_Entity_EntityDescription = ReAct_Title_Entity_EntityDescription.drop_duplicates(subset=['ReACT_number', 'Entity'])
ReAct_Title_Entity_EntityDescription.reset_index(inplace=True, drop=True)
ReAct_Title_Entity_EntityDescription
# Out:
#     ReACT_number                                        ReACT_title  \
# 0        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 1        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 2        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 3       ReACT-10                 Offer job support to the newcomer.
# 4       ReACT-10                 Offer job support to the newcomer.
# ..           ...                                                ...
# 142     ReACT-87    Follow up newcomers on both success and failure
# 143     ReACT-88  Assign an experienced team member to coach and...
# 144     ReACT-89  Grant the newcomer freedom: Encourage and allo...
# 145      ReACT-9      Grant newcomer access to the main repository.
# 146     ReACT-90  Establish a personalized integration plan: Out...
#
#                    Entity                                  EntityDescription
# 0     Project Maintainers  Project maintainers in open-source software de...
# 1         Project Leaders  Project leaders in open-source software develo...
# 2      Community Managers  Community managers in open source oversee posi...
# 3        Project Managers  In open-source software development, project m...
# 4                  Owners  In open-source software development, owners ty...
# ..                    ...                                                ...
# 142               Mentors  Mentors in open-source software development ar...
# 143               Mentors  Mentors in open-source software development ar...
# 144  Community Moderators  Community moderators in open-source software d...
# 145       Project Leaders  Project leaders in open-source software develo...
# 146      Project Managers  In open-source software development, project m...
#
# [147 rows x 4 columns]

# %%
df = ReAct_Title_Entity_EntityDescription
ReACT_number = df['ReACT_number'].values

ReACT_Title = df['ReACT_title'].values

Entity = df['Entity'].values
df['EntityDescription'] = df['EntityDescription'].apply(wrap_text)
EntityDescription = df['EntityDescription'].values


net = Network(directed =True)
for i in range(0,len(ReACT_number)):
  # print(actionable[i])
  net.add_node(ReACT_number[i], label=ReACT_number[i], title=ReACT_Title[i])
  net.add_node(Entity[i], label=Entity[i], title=EntityDescription[i], color = "#98BF64",shape='box')
  net.add_edge(Entity[i], ReACT_number[i], color = "#32612D")

# net.show_buttons(filter_=['physics'])
net.show('IG_Entity.html')
# Out:
# <ipython-input-44-04ac39270477>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
unique_counts = ReAct_Title_Entity_EntityDescription['Entity'].value_counts().reset_index()

# Rename the columns for clarity
unique_counts.columns = ['Entity Responsible for Performing ReACTs', 'Count of ReACTs']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']


# Create an interactive bar plot using Plotly Express
fig = px.bar(unique_counts, x='Count of ReACTs', y='Entity Responsible for Performing ReACTs', color='Entity Responsible for Performing ReACTs', color_discrete_sequence=darker_shades, orientation='h')

# Save the plot as an HTML file
fig.write_html('BarPlot_Entity.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ddcca5c-5fdc-4a37-bd41-988ee36b3b33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ddcca5c-5fdc-4a37-bd41-988ee36b3b33")) {                    Plotly.newPlot(                        "6ddcca5c-5fdc-4a37-bd41-988ee36b3b33",                        [{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Project Maintainers","marker":{"color":"darkred","pattern":{"shape":""}},"name":"Project Maintainers","offsetgroup":"Project Maintainers","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["Project Maintainers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Project Leaders","marker":{"color":"lightblue","pattern":{"shape":""}},"name":"Project Leaders","offsetgroup":"Project Leaders","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y":["Project Leaders"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community Managers","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"Community Managers","offsetgroup":"Community Managers","orientation":"h","showlegend":true,"textposition":"auto","x":[13],"xaxis":"x","y":["Community Managers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mentors","marker":{"color":"#FFABAB","pattern":{"shape":""}},"name":"Mentors","offsetgroup":"Mentors","orientation":"h","showlegend":true,"textposition":"auto","x":[11],"xaxis":"x","y":["Mentors"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Developers","marker":{"color":"#91a8a8","pattern":{"shape":""}},"name":"Developers","offsetgroup":"Developers","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["Developers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Collaboration Coordinators","marker":{"color":"#95ab8a","pattern":{"shape":""}},"name":"Collaboration Coordinators","offsetgroup":"Collaboration Coordinators","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["Collaboration Coordinators"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Project Managers","marker":{"color":"#00a86b","pattern":{"shape":""}},"name":"Project Managers","offsetgroup":"Project Managers","orientation":"h","showlegend":true,"textposition":"auto","x":[9],"xaxis":"x","y":["Project Managers"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Entity Responsible for Performing ReACTs=%{y}\u003cbr\u003eCount of ReACTs=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Code Reviewers","marker":{"color":"#8E44AD","pattern":{"shape":""}},"name":"Code Reviewers","offsetgroup":"Code Reviewers","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x ...

# %%
import plotly.graph_objects as go
import plotly.io as pio

subject = ReAct_Title_Entity_EntityDescription['Entity']
score = ReAct_Title_Entity_EntityDescription['ReACT_number']

TextToShow = "<b>"+ReAct_Title_Entity_EntityDescription['Entity'] + " are Responsible for Performing </b>"
TextToShow += "<b>"+ReAct_Title_Entity_EntityDescription['ReACT_number'] +"</b>"+ "<br>"
TextToShow += "<b>"+ReAct_Title_Entity_EntityDescription['ReACT_number']+"</b>: "
TextToShow += ReAct_Title_Entity_EntityDescription['ReACT_title'].apply(wrap_text_withBR)
TextToShow += "<br><b>" +ReAct_Title_Entity_EntityDescription['Entity'] +": </b>"
TextToShow += ReAct_Title_Entity_EntityDescription['EntityDescription'].apply(wrap_text_withBR)


data = [dict(
  type = 'scatter',
  x = subject,
  y = score,
  mode = 'markers',
  text = TextToShow,  # Set the 'text' property to the Y-axis values
  transforms = [dict(
    type = 'groupby',
    groups = subject
  )],
   marker=dict(
        symbol='square',  # Set the shape of the marker (e.g., 'circle', 'square', 'diamond', etc.)
        size=10  # Set the size of the circles (adjust as needed)

    )
)]

layout = dict(xaxis=dict(title='Features'),
              yaxis=dict(title='ReACT Number'),
              height=1200,
              width=1100)

fig_dict = dict(data=data, layout=layout)
pio.show(fig_dict, validate=False)
pio.write_html(fig_dict, file='SP_Entity.html', auto_open=True, validate=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1bf21547-79cd-432a-a790-d119c693fa1f" class="plotly-graph-div" style="height:1200px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bf21547-79cd-432a-a790-d119c693fa1f")) {                    Plotly.newPlot(                        "1bf21547-79cd-432a-a790-d119c693fa1f",                        [{"type":"scatter","x":["Project Maintainers","Project Leaders","Community Managers","Project Managers","Owners","Core Developers","Sponsors","Sponsors","Developers","Project Maintainers","Project Leaders","Project Leaders","Mentors","Core Developers","Mentors","Project Maintainers","Project Leaders","Community Moderators","Project Maintainers","Project Leaders","Project Maintainers","Project Leaders","Community Managers","Project Maintainers","Project Leaders","Mentors","Project Maintainers","Project Leaders","Community Managers","Project Maintainers","Project Leaders","Project Maintainers","Developers","Community Managers","Project Maintainers","Documentation Team","Contributors","Developers","Quality Assurance Team","Contributors","Architects","Design Team","Developers","Developers","Code Reviewers","Project Maintainers","Project Maintainers","Project Leaders","Architects","Developers","Technical Leads","Project Maintainers","Project Maintainers","Community Managers","Developers","Project Maintainers","Community Managers","Contributors","Project Maintainers","Project Maintainers","Community Managers","Project Leaders","Project Maintainers","Technical Leads","Community Managers","Project Maintainers","Project Leaders","Project Maintainers","Community Managers","Architects","Project Maintainers","Project Leaders","Project Maintainers","Collaboration Coordinators","Project Maintainers","Collaboration Coordinators","Project Maintainers","Collaboration Coordinators","Project Maintainers","Collaboration Coordinators","Project Maintainers","Collaboration Coordinators","Project Maintainers","Collaboration Coordinators","Project Leaders","Community Managers","Project Maintainers","Project Managers","Project Leaders","Project Managers","Project Leaders","Project Managers","Project Leaders","Community Managers","Developers","Project Maintainers","Project Managers","Project Leaders","Developers","Project Leaders","Owners","Project Leaders","Community Managers","Project Leaders","Collaboration Coordinators","Collaboration Coordinators","Mentors","Documentation Team","Project Leaders","Core Developers","Community Managers","Project Managers","Mentors","Code Reviewers","Code Reviewers","Project Leaders","Quality Assurance Team","Project Managers","Project Leaders","Code Reviewers","Project Leaders","Developers","Contributors","Code Reviewers","Quality Assurance Team","Code Reviewers","Code Reviewers","Technical Leads","Project Managers","Architects","Collaboration Coordinators","Collaboration Coordinators","Project Leaders","Core Developers","Contributors","Project Leaders","Documentation Team","Community Moderators","Mentors","Mentors","Mentors","Mentors","Mentors","Mentors","Community Moderators","Project Leaders","Project Managers"],"y":["ReACT-1","ReACT-1","ReACT-1","ReACT-10","ReACT-10","ReACT-11","ReACT-12","ReACT-13","ReACT-14","ReACT-14","ReACT-15","ReACT-16","ReACT-17","ReACT-17","ReACT-18","ReACT-18","ReACT-18","ReACT-19","ReACT-19","ReACT-19","ReACT-2","ReACT-2","ReACT-20","ReACT-20","ReACT-20","ReACT-21","ReACT-21","ReACT-21","ReACT-22","ReACT-22","ReACT-22","ReACT-23","ReACT-23","ReACT-24","ReACT-25","ReACT-25","ReACT-25","ReACT-26","ReACT-26","ReACT-26","ReACT-28","ReACT-28","ReACT-28","ReACT-29","ReACT-29","ReACT-29","ReACT-3","ReACT-3","ReACT-30","ReACT-31","ReACT-31","ReACT-31","ReACT-32","ReACT-32","ReACT-32","ReACT-33","ReACT-33","ReACT-33","ReACT-34","ReACT-35","R ...

# %% [markdown]
# #Plotting ReAct and Features - Network Diagram

# %%
MainSheet
# Out:
#    ReACT_number   Unnamed: 1  \
# 0       ReACT-1  not minable
# 1      ReACT-10          NaN
# 2      ReACT-11          NaN
# 3      ReACT-11          NaN
# 4      ReACT-11          NaN
# ..          ...          ...
# 92     ReACT-87          NaN
# 93     ReACT-88          NaN
# 94     ReACT-89          NaN
# 95      ReACT-9          NaN
# 96     ReACT-90          NaN
#
#                                           ReACT_title               Class  \
# 0   Ensure a team of friendly and supportive\ndeve...   Individual, Group
# 1                  Offer job support to the newcomer.          Foundation
# 2                  Keep the project small and simple.  Project, Ecosystem
# 3                  Keep the project small and simple.  Project, Ecosystem
# 4                  Keep the project small and simple.  Project, Ecosystem
# ..                                                ...                 ...
# 92    Follow up newcomers on both success and failure          Individual
# 93  Assign an experienced team member to coach and...            Pairwise
# 94  Grant the newcomer freedom: Encourage and allo...   Individual, Group
# 95      Grant newcomer access to the main repository.                Code
# 96  Establish a personalized integration plan: Out...             Project
#
#                       Entity_responsible  \
# 0   Project Maintainers, Project Leaders
# 1               Project Managers, Owners
# 2                        Core Developers
# 3                        Core Developers
# 4                        Core Developers
# ..                                   ...
# 92                               Mentors
# 93                               Mentors
# 94                  Community Moderators
# 95                       Project Leaders
# 96                      Project Managers
#
#                                              Features  \
# 0                                         num_act_dev
# 1                            num_act_dev, c_long_tail
# 2                                         num_act_dev
# 3                                         num_commits
# 4                                top_c_fract, c_nodes
# ..                                                ...
# 92  c_nodes, c_edges, c_long_tail, c_mean_degree, ...
# 93  c_nodes, c_edges, c_long_tail, c_mean_degree, ...
# 94  e_interruption, c_nodes, c_edges, c_long_tail,...
# 95                           num_act_dev, c_long_tail
# 96       c_nodes, c_edges, c_long_tail, c_mean_degree
#
#     Quatative/Qualatitative             References  \
# 0                       NaN  No. of reference: 3\n
# 1                       NaN    No. of reference: 1
# 2                       NaN  No. of reference: 3\n
# 3                       NaN    No. of reference: 1
# 4                       NaN    No. of reference: 1
# ..                      ...                    ...
# 92                      NaN    No. of reference: 1
# 93                      NaN    No. of reference: 1
# 94                      NaN    No. of reference: 1
# 95                      NaN    No. of reference: 1
# 96                      NaN    No. of reference: 1
#
#                                              Articles
# 0   1. G. Avelino, E. Constantinou, M. T. Valente ...
# 1   1. G. Avelino, E. Constantinou, M. T. Valente ...
# 2   1. G. Avelino, E. Constantinou, M. T. Valente ...
# 3   1. Carsten Kolassa, Dirk Riehle, and Michel A....
# 4   1. Jailton Coelho, Marco Tulio Valente, Lucian...
# ..                                                ...
# 92  1. Sholler D, Steinmacher I, Ford D, Averick M...
# 93  1. G. Matturro, K. Barrella and P. Benitez, "D...
# 94  1. G. Matturro, K. Barrella and P. Benitez, "D...
# 95  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 96  1. G. Matturro, K. Barrella and P. Benitez, "D...
#
# [97 rows x 9 columns]

# %%
ReActAndFeature = MainSheet[['ReACT_number', 'Features']]

b = DataFrame(ReActAndFeature.Features.str.split(',').tolist(), index=ReActAndFeature.ReACT_number).stack()
b = b.reset_index()[[0, 'ReACT_number']]
b.columns = ['Features', 'ReACT_number'] # renaming var1
ReActAndFeature  = b
ReActAndFeature = processing(ReActAndFeature)
ReActAndFeature
# Out:
#           Features ReACT_number
# 0      num_act_dev      ReACT-1
# 1      num_act_dev     ReACT-10
# 2      c_long_tail     ReACT-10
# 3      num_act_dev     ReACT-11
# 4      num_commits     ReACT-11
# ..             ...          ...
# 221    c_long_tail      ReACT-9
# 222        c_nodes     ReACT-90
# 223        c_edges     ReACT-90
# 224    c_long_tail     ReACT-90
# 225  c_mean_degree     ReACT-90
#
# [226 rows x 2 columns]

# %%
ReActTitleFeature = pd.merge(ReActAndTitle, ReActAndFeature, on='ReACT_number', how='outer')
ReActTitleFeature['FeatureDescription'] = None
ReActAndReference = MainSheet[['ReACT_number', 'References', 'Articles']]

ReActFeatureDescription = ReActTitleFeature


for i in range(0,len(ReActFeatureDescription)):
 ReActFeatureDescription.FeatureDescription[i] = FeatureDescription_Dict[ReActFeatureDescription.Features[i].lstrip().rstrip()]
ReAct_Title_Feature_FeatureDescription = ReActFeatureDescription
ReAct_Title_Feature_FeatureDescription_Reference = pd.merge(ReAct_Title_Feature_FeatureDescription, ReActAndReference, on='ReACT_number', how='outer')
ReAct_Title_Feature_FeatureDescription_Reference

#The following line is added to remove the exact duplicate rows based on ['ReACT_number', 'Features']
ReAct_Title_Feature_FeatureDescription_Reference = ReAct_Title_Feature_FeatureDescription_Reference.drop_duplicates(subset=['ReACT_number', 'Features'])
ReAct_Title_Feature_FeatureDescription_Reference.reset_index(inplace=True, drop=True)
ReAct_Title_Feature_FeatureDescription_Reference
# Out:
#     ReACT_number                                        ReACT_title  \
# 0        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 1        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 2        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 3        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# 4        ReACT-1  Ensure a team of friendly and supportive\ndeve...
# ..           ...                                                ...
# 219      ReACT-9      Grant newcomer access to the main repository.
# 220     ReACT-90  Establish a personalized integration plan: Out...
# 221     ReACT-90  Establish a personalized integration plan: Out...
# 222     ReACT-90  Establish a personalized integration plan: Out...
# 223     ReACT-90  Establish a personalized integration plan: Out...
#
#           Features                                 FeatureDescription  \
# 0      num_act_dev  The number of Active Developers is the count o...
# 1          c_nodes  The number of active nodes in the technical ne...
# 2          c_edges  The number of active edges in the technical ne...
# 3      c_long_tail  The degree of the 75𝑡ℎ percentile of nodes in ...
# 4    c_mean_degree  sum of all nodes’ degree divided by the number...
# ..             ...                                                ...
# 219    c_long_tail  The degree of the 75𝑡ℎ percentile of nodes in ...
# 220        c_nodes  The number of active nodes in the technical ne...
# 221        c_edges  The number of active edges in the technical ne...
# 222    c_long_tail  The degree of the 75𝑡ℎ percentile of nodes in ...
# 223  c_mean_degree  sum of all nodes’ degree divided by the number...
#
#                 References                                           Articles
# 0    No. of reference: 3\n  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 1    No. of reference: 3\n  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 2    No. of reference: 3\n  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 3    No. of reference: 3\n  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 4    No. of reference: 3\n  1. G. Avelino, E. Constantinou, M. T. Valente ...
# ..                     ...                                                ...
# 219    No. of reference: 1  1. G. Avelino, E. Constantinou, M. T. Valente ...
# 220    No. of reference: 1  1. G. Matturro, K. Barrella and P. Benitez, "D...
# 221    No. of reference: 1  1. G. Matturro, K. Barrella and P. Benitez, "D...
# 222    No. of reference: 1  1. G. Matturro, K. Barrella and P. Benitez, "D...
# 223    No. of reference: 1  1. G. Matturro, K. Barrella and P. Benitez, "D...
#
# [224 rows x 6 columns]

# %%
df = ReAct_Title_Feature_FeatureDescription_Reference
ReACT_number = df['ReACT_number'].values
ReACT_Title = df['ReACT_title'].values
Feature = df['Features'].values
df['FeatureDescription'] = df['FeatureDescription'].apply(wrap_text)
FeatureDescription = df['FeatureDescription'].values

Edges = ReAct_Title_Feature_FeatureDescription_Reference['References'].values+'\n Reference(s) \n'+ReAct_Title_Feature_FeatureDescription_Reference['Articles'].apply(wrap_text)



net = Network(directed =True)
for i in range(0,len(ReACT_number)):
 # print(actionable[i])
 net.add_node(ReACT_number[i], label=ReACT_number[i], title=ReACT_Title[i])
 net.add_node(Feature[i], label=Feature[i], title=FeatureDescription[i], color = "#E07772",shape='box')
 net.add_edge(ReACT_number[i], Feature[i], weight=extract_numbers(Edges[i]), title=Edges[i], color = "#898980")

#  net.add_edge(ReACT_number[i], Feature[i], weight=extract_numbers(Edges[i]), title=Edges[i], color = "#898980")

# net.show_buttons(filter_=['physics'])
net.show('IG_Feature.html')

# %%
ReAct_Title_Feature_FeatureDescription_Reference['Features'].value_counts()
# Out:
# num_act_dev       46
# c_nodes           29
# c_edges           25
# c_long_tail       20
# c_mean_degree     14
# top_c_fract       14
# num_commits       12
# c_c_coef          12
# e_edges           12
# num_files          8
# e_mean_degree      6
# e_nodes            6
# e_long_tail        6
# e_c_coef           5
# top_e_fract        4
# e_interruption     3
# num_emails         2
# Name: Features, dtype: int64

# %%
unique_counts = ReAct_Title_Feature_FeatureDescription_Reference['Features'].value_counts().reset_index()

# Rename the columns for clarity
unique_counts.columns = ['Feature Name', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']


# Create an interactive bar plot using Plotly Express
fig = px.pie(unique_counts, names='Feature Name', values='Count', color='Feature Name', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('PiePlot_Feature.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0bda42e3-e9da-49de-a75f-5420d4ca6700" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bda42e3-e9da-49de-a75f-5420d4ca6700")) {                    Plotly.newPlot(                        "0bda42e3-e9da-49de-a75f-5420d4ca6700",                        [{"customdata":[["num_act_dev"],["c_nodes"],["c_edges"],["c_long_tail"],["c_mean_degree"],["top_c_fract"],["num_commits"],["c_c_coef"],["e_edges"],["num_files"],["e_mean_degree"],["e_nodes"],["e_long_tail"],["e_c_coef"],["top_e_fract"],["e_interruption"],["num_emails"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Feature Name=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["num_act_dev","c_nodes","c_edges","c_long_tail","c_mean_degree","top_c_fract","num_commits","c_c_coef","e_edges","num_files","e_mean_degree","e_nodes","e_long_tail","e_c_coef","top_e_fract","e_interruption","num_emails"],"legendgroup":"","marker":{"colors":["darkred","lightblue","lightgreen","#FFABAB","#91a8a8","#95ab8a","#00a86b","#8E44AD","#2E4053","#D35400","#a37b65","#6C5B7B","#C0C999","#7D8CC4","#FFA07A","#88D8B0","#826c7F"]},"name":"","showlegend":true,"values":[46,29,25,20,14,14,12,12,12,8,6,6,6,5,4,3,2],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d" ...

# %%
import plotly.graph_objects as go
import plotly.io as pio



subject = ReAct_Title_Feature_FeatureDescription_Reference['Features']
score = ReAct_Title_Feature_FeatureDescription_Reference['ReACT_number']


TextToShow = ReAct_Title_Feature_FeatureDescription_Reference['ReACT_number'] + " Positively Impacts "
TextToShow += ReAct_Title_Feature_FeatureDescription_Reference['Features'] + "<br>"
TextToShow +=  "<b>"+ReAct_Title_Feature_FeatureDescription_Reference['ReACT_number']+"</b>: "
TextToShow += ReAct_Title_Feature_FeatureDescription_Reference['ReACT_title'].apply(wrap_text_withBR)
TextToShow += "<br><b>" +ReAct_Title_Feature_FeatureDescription_Reference['Features'] +": </b>"
TextToShow += ReAct_Title_Feature_FeatureDescription_Reference['FeatureDescription'].apply(wrap_text_withBR)

data = [dict(
  type = 'scatter',
  x = subject,
  y = score,
  mode = 'markers',
  text = TextToShow,
  transforms = [dict(
    type = 'groupby',
    groups = subject
  )],
   marker=dict(
        symbol='square',  # Set the shape of the marker (e.g., 'circle', 'square', 'diamond', etc.)
        size=10  # Set the size of the circles (adjust as needed)

    )
)]

layout = dict(xaxis=dict(title='Features'),
              yaxis=dict(title='ReACT Number'),
              height=1200,
              width=800)

fig_dict = dict(data=data, layout=layout)
pio.show(fig_dict, validate=False)
pio.write_html(fig_dict, file='SP_Feature.html', auto_open=True, validate=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c511482c-3216-426d-aae6-11e2cfcc5f9e" class="plotly-graph-div" style="height:1200px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c511482c-3216-426d-aae6-11e2cfcc5f9e")) {                    Plotly.newPlot(                        "c511482c-3216-426d-aae6-11e2cfcc5f9e",                        [{"type":"scatter","x":["num_act_dev","c_nodes","c_edges","c_long_tail","c_mean_degree","e_nodes","e_edges","e_mean_degree","e_long_tail","num_act_dev","c_long_tail","num_act_dev","num_commits","top_c_fract","c_nodes","num_act_dev","top_c_fract","c_nodes","num_act_dev","num_act_dev","num_act_dev","num_act_dev","num_act_dev","c_long_tail","e_interruption","c_nodes","c_edges","c_long_tail","c_mean_degree","num_act_dev","c_long_tail","num_act_dev","num_act_dev","num_act_dev","c_long_tail","num_act_dev","c_long_tail","num_act_dev","c_long_tail","num_act_dev","c_nodes","c_edges","c_long_tail","c_mean_degree","num_act_dev","top_c_fract","num_act_dev","top_c_fract","c_nodes","num_act_dev","top_c_fract","c_nodes","num_act_dev","top_c_fract","c_nodes","num_act_dev","top_c_fract","top_e_fract","c_nodes","num_commits","num_act_dev","num_act_dev","top_c_fract","c_nodes","num_act_dev","top_c_fract","c_nodes","num_act_dev","top_c_fract","c_nodes","num_act_dev","num_act_dev","num_commits","num_act_dev","top_c_fract","top_e_fract","c_nodes","num_act_dev","num_act_dev","num_act_dev","num_act_dev","c_edges","c_c_coef","c_edges","c_c_coef","e_edges","e_c_coef","c_edges","c_c_coef","c_edges","c_c_coef","c_edges","c_c_coef","c_edges","c_c_coef","c_edges","c_c_coef","e_edges","e_c_coef","c_edges","c_c_coef","e_edges","e_c_coef","c_edges","c_c_coef","e_edges","e_c_coef","c_edges","c_c_coef","e_edges","e_c_coef","num_act_dev","top_c_fract","top_e_fract","c_nodes","num_commits","num_act_dev","top_c_fract","top_e_fract","c_nodes","num_commits","num_act_dev","num_commits","num_commits","c_nodes","num_commits","c_edges","c_c_coef","num_act_dev","num_act_dev","num_emails","c_nodes","c_mean_degree","e_edges","num_act_dev","num_act_dev","num_act_dev","num_act_dev","top_c_fract","c_nodes","num_act_dev","c_edges","c_c_coef","num_commits","c_nodes","num_act_dev","num_commits","num_commits","num_commits","num_files","num_act_dev","num_files","num_files","num_files","num_files","num_files","num_files","num_files","num_emails","e_nodes","e_edges","e_mean_degree","e_long_tail","num_act_dev","c_nodes","c_edges","c_long_tail","c_mean_degree","c_nodes","c_edges","c_long_tail","c_mean_degree","c_nodes","c_edges","c_long_tail","c_mean_degree","e_nodes","e_edges","e_mean_degree","e_long_tail","c_nodes","c_edges","c_long_tail","c_mean_degree","e_interruption","c_nodes","c_edges","c_long_tail","c_mean_degree","c_nodes","c_edges","c_long_tail","c_mean_degree","e_nodes","e_edges","e_mean_degree","e_long_tail","c_nodes","c_edges","c_long_tail","c_mean_degree","e_nodes","e_edges","e_mean_degree","e_long_tail","c_nodes","c_edges","c_long_tail","c_mean_degree","e_nodes","e_edges","e_mean_degree","e_long_tail","e_interruption","c_nodes","c_edges","c_long_tail","c_mean_degree","num_act_dev","c_long_tail","c_nodes","c_edges","c_long_tail","c_mean_degree"],"y":["ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-1","ReACT-10","ReACT-10","ReACT-11","ReACT-11","ReACT-11","ReACT-11","ReACT-12","ReACT-12","ReACT-12","ReACT-13","ReACT-14","ReACT-15","ReACT-16","ReACT-17","ReACT-17","ReACT-18","ReACT-18","ReACT-18","ReACT-18","ReACT-18","ReACT-19","ReACT-19","ReACT-2","ReACT-20","ReACT-21","ReACT-21","ReACT-22","ReACT-22","ReACT-23","ReACT-23","ReACT-24","ReACT-25","ReACT-25","ReACT-25","ReACT-25","ReACT-25","ReACT-25","ReACT-26","ReACT-26","ReACT-26","ReACT-28","ReACT-28","ReACT-28","ReACT-29","ReA ...

# %% [markdown]
# #WordClouds

# %%
# !pip install wordcloud matplotlib
import pandas as pd
import re
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Keyword Wordcloud -  ReACT Driven
#
# ### Wordcloud generating from the keywords of the article, from which ReACT could be driven

# %%
df = pd.read_excel("article.xlsx")
df['Keyword'] = df['Keyword'].str.lower()
df['Article'] = df['Article'].str.lower()
df = df[df['ReACTs'] != 'No ReACT could be derived from the article']
df = df.dropna(subset=['ReACTs'])
df = df[~df['ReACTs'].str.contains('Article excluded')]

# dropping the rows that contains 'No ReACT...' value in the ReACT column
# dropping the rows that contains empty value in the ReACT column
# dropping the rows that contains 'Article excluded' in the ReACT column

# %%
dfKeywordReACTDriven = df.dropna(subset=['Keyword'])
KeywordReACTDriven = dfKeywordReACTDriven['Keyword']

all_text = ' '.join(KeywordReACTDriven)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-21c279d6cf48> in <cell line: 7>()
#       5
#       6 # Generate the word cloud
# ----> 7 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)
#       8
#       9 # Display the generated word cloud using matplotlib
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Title Wordcloud - ReACT Driven
# ### Wordcloud generating from the Titles of the article, from which ReACT could be driven

# %%
dfTitleReACTDriven = df.dropna(subset=['Article'])
TitleReACTDriven = dfTitleReACTDriven['Article']

all_text = ' '.join(TitleReACTDriven)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50).generate(all_text)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5a0347660c71> in <cell line: 7>()
#       5
#       6 # Generate the word cloud
# ----> 7 wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50).generate(all_text)
#       8
#       9 # Display the generated word cloud using matplotlib
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Keyword Wordcloud - NOT ReACT Driven
#
# ### Wordcloud generating from the keywords of articles, from which NO ReACT could be derived

# %%
df = pd.read_excel("article.xlsx")
df['Keyword'] = df['Keyword'].str.lower()
df['Article'] = df['Article'].str.lower()
df = df[df['ReACTs'] == 'No ReACT could be derived from the article']

# dropping the rows that contains 'Article excluded' in the ReACT column

# %%
dfKeywordNOTReACTDriven = df.dropna(subset=['Keyword'])
KeywordNOTReACTDriven = dfKeywordNOTReACTDriven['Keyword']

all_text = ' '.join(KeywordNOTReACTDriven)

all_text = all_text.replace(",", "")
all_text = re.sub(' +', ' ', all_text)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50, repeat=False).generate(all_text)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-19124e7da479> in <cell line: 10>()
#       8
#       9 # Generate the word cloud
# ---> 10 wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50, repeat=False).generate(all_text)
#      11
#      12 # Display the generated word cloud using matplotlib
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Title Wordcloud - NOT ReACT Driven
#
# ### Wordcloud generating from the Title of articles, from which NO ReACT could be derived

# %%
dfTitleNOTReACTDriven = df.dropna(subset=['Article'])
TitleNOTReACTDriven = dfTitleNOTReACTDriven['Article']

all_text = ' '.join(TitleNOTReACTDriven)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50).generate(all_text)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-87296f338f1e> in <cell line: 7>()
#       5
#       6 # Generate the word cloud
# ----> 7 wordcloud = WordCloud(width=800, height=400, background_color='white', max_words = 50).generate(all_text)
#       8
#       9 # Display the generated word cloud using matplotlib
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Venue (Conference) - NOT ReACT Driven

# %%
# !pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in /usr/local/lib/python3.10/dist-packages (0.2.1)

# %%
df = pd.read_excel("article.xlsx")
df['Venue'] = df['Venue'].str.lstrip()
df['Venue'] = df['Venue'].str.rstrip()
df = df[df['Type'] == 'Conference']

unique_counts = df['Venue'].value_counts().reset_index()

unique_counts = unique_counts[unique_counts['index'] != 'Grey Literature']
unique_counts = unique_counts.head(10)
print(unique_counts)

import random
# Rename the columns for clarity
unique_counts.columns = ['Publication Venue', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']
random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.pie(unique_counts, names='Publication Venue', values='Count', color='Publication Venue', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('PiePlot_Venues_C_All.html')
# fig.write_image("pub_conf_analyzed.png")
fig.show()
# Out:
#         index  Venue
# 0        ICSE     17
# 1  IFIP ICOSS      9
# 2         MSR      8
# 3        CSCW      4
# 4       HICSS      4
# 5         FSE      4
# 6        ESEM      3
# 7        ICSM      3
# 8  OPENCOLLAB      3
# 9       AMCIS      2
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="558a45de-8969-493f-a3f4-caacdf9b1372" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("558a45de-8969-493f-a3f4-caacdf9b1372")) {                    Plotly.newPlot(                        "558a45de-8969-493f-a3f4-caacdf9b1372",                        [{"customdata":[["ICSE"],["IFIP ICOSS"],["MSR"],["CSCW"],["HICSS"],["FSE"],["ESEM"],["ICSM"],["OPENCOLLAB"],["AMCIS"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Publication Venue=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["ICSE","IFIP ICOSS","MSR","CSCW","HICSS","FSE","ESEM","ICSM","OPENCOLLAB","AMCIS"],"legendgroup":"","marker":{"colors":["#F5A623","#FFA07A","#A77B7B","#C0C999","#D35400","#BAC9FF","#7A9E9F","#7C83FD","darkred","#D2F2D2"]},"name":"","showlegend":true,"values":[17,9,8,4,4,4,3,3,3,2],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f ...

# %% [markdown]
# ### Venue (Journal) - NOT ReACT Driven

# %%
df = pd.read_excel("article.xlsx")
df['Venue'] = df['Venue'].str.lstrip()
df['Venue'] = df['Venue'].str.rstrip()
df = df[df['Type'] == 'Journal']

unique_counts = df['Venue'].value_counts().reset_index()

unique_counts = unique_counts[unique_counts['index'] != 'Grey Literature']
unique_counts = unique_counts.head(10)
print(unique_counts)

import random
# Rename the columns for clarity
unique_counts.columns = ['Publication Venue', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']
random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.pie(unique_counts, names='Publication Venue', values='Count', color='Publication Venue', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('PiePlot_Venues_J_All.html')
# fig.write_image("pub_journal_analyzed.png")
fig.show()
# Out:
#            index  Venue
# 0            IST      4
# 1            SEM      3
# 2            ISR      3
# 3            JSS      2
# 4            CHB      2
# 5  IEEE Software      2
# 6            ESE      2
# 7            AIS      2
# 8           TIMR      2
# 9            ORM      1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee638553-6d99-4dcf-b572-cf4d266248f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee638553-6d99-4dcf-b572-cf4d266248f2")) {                    Plotly.newPlot(                        "ee638553-6d99-4dcf-b572-cf4d266248f2",                        [{"customdata":[["IST"],["SEM"],["ISR"],["JSS"],["CHB"],["IEEE Software"],["ESE"],["AIS"],["TIMR"],["ORM"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Publication Venue=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["IST","SEM","ISR","JSS","CHB","IEEE Software","ESE","AIS","TIMR","ORM"],"legendgroup":"","marker":{"colors":["darkred","#E47878","#95ab8a","#8E44AD","#00a86b","#FAE5D3","#91a8a8","#2E4053","#D8D8D8","#649E7D"]},"name":"","showlegend":true,"values":[4,3,3,2,2,2,2,2,2,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{ ...

# %% [markdown]
# ### Venue (Conference) - ReACT Driven

# %%
df = pd.read_excel("article.xlsx")
df['Venue'] = df['Venue'].str.lstrip()
df['Venue'] = df['Venue'].str.rstrip()
df = df[df['ReACTs'] != 'No ReACT could be derived from the article']
df = df.dropna(subset=['ReACTs'])
df = df[~df['ReACTs'].str.contains('Article excluded')]
df = df[df['Type'] == 'Conference']

# dropping the rows that contains 'No ReACT...' value in the ReACT column
# dropping the rows that contains empty value in the ReACT column
# dropping the rows that contains 'Article excluded' in the ReACT column

unique_counts = df['Venue'].value_counts().reset_index()
unique_counts = unique_counts[unique_counts['index'] != 'Grey Literature']
unique_counts = unique_counts.head(10)
print(unique_counts)

import random
# Rename the columns for clarity
unique_counts.columns = ['Publication Venue', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']
random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.pie(unique_counts, names='Publication Venue', values='Count', color='Publication Venue', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('PiePlot_Venues_C_ReACTDriven.html')

fig.write_image("pub_conf_react.png")

fig.show()
# Out:
#           index  Venue
# 0          ESEM      2
# 1          ICSE      2
# 2          SBES      2
# 3    IFIP ICOSS      1
# 4          CSCW      1
# 5          ICSE      1
# 6         ICGSE      1
# 7  IFIP ICOSS\n      1
# 8       WikiSym      1
# 9           MSR      1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd38a821-96dd-468d-873d-f57631f62858" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd38a821-96dd-468d-873d-f57631f62858")) {                    Plotly.newPlot(                        "cd38a821-96dd-468d-873d-f57631f62858",                        [{"customdata":[["ESEM"],["ICSE"],["SBES"],["IFIP ICOSS"],["CSCW"],[" ICSE"],["ICGSE"],["IFIP ICOSS\n"],["WikiSym"],["MSR"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Publication Venue=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["ESEM","ICSE","SBES","IFIP ICOSS","CSCW"," ICSE","ICGSE","IFIP ICOSS\n","WikiSym","MSR"],"legendgroup":"","marker":{"colors":["#A77B7B","#826c7F","#00a86b","#BAC9FF","#91a8a8","#D8D8D8","#D35400","#F5A623","#CAAE77","#FAE5D3"]},"name":"","showlegend":true,"values":[2,2,2,1,1,1,1,1,1,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"co ...

# %% [markdown]
# ### Venue (Journal) - ReACT Driven

# %%
df = pd.read_excel("article.xlsx")
df['Venue'] = df['Venue'].str.lstrip()
df['Venue'] = df['Venue'].str.rstrip()
df = df[df['ReACTs'] != 'No ReACT could be derived from the article']
df = df.dropna(subset=['ReACTs'])
df = df[~df['ReACTs'].str.contains('Article excluded')]
df = df[df['Type'] == 'Journal']

# dropping the rows that contains 'No ReACT...' value in the ReACT column
# dropping the rows that contains empty value in the ReACT column
# dropping the rows that contains 'Article excluded' in the ReACT column

unique_counts = df['Venue'].value_counts().reset_index()
unique_counts = unique_counts[unique_counts['index'] != 'Grey Literature']
unique_counts = unique_counts.head(10)
print(unique_counts)

import random
# Rename the columns for clarity
unique_counts.columns = ['Publication Venue', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']
random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.pie(unique_counts, names='Publication Venue', values='Count', color='Publication Venue', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('PiePlot_Venues_J_ReACTDriven.html')
fig.write_image("pub_journal_react.png")
fig.show()
# Out:
#       index  Venue
# 0       IEP      1
# 1       SCP      1
# 2     IJERT      1
# 3       IST      1
# 4  PLOS ONE      1
# 5       SEM      1
# 6        CB      1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c7a3fde3-335a-4a4d-8469-038a5a4380e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7a3fde3-335a-4a4d-8469-038a5a4380e3")) {                    Plotly.newPlot(                        "c7a3fde3-335a-4a4d-8469-038a5a4380e3",                        [{"customdata":[["IEP"],["SCP"],["IJERT"],["IST"],["PLOS ONE"],["SEM"],["CB"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Publication Venue=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["IEP","SCP","IJERT","IST","PLOS ONE","SEM","CB"],"legendgroup":"","marker":{"colors":["#D8D8D8","#a37b65","#E47878","#FFA07A","#A77B7B","#D8D8D8","lightblue"]},"name":"","showlegend":true,"values":[1,1,1,1,1,1,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %% [markdown]
# ###Years - All Analyzed

# %%
df = pd.read_excel("article.xlsx")
unique_counts_all = df['Publication Year'].value_counts().reset_index()

unique_counts_all.columns = ['year', 'year_count']
unique_counts_all

# Define the bins for grouping the years
bins = [2000, 2004, 2008, 2012, 2016, 2020, 2024]

# Define labels for the groups
# labels = ['2001-2005', '2006-2010', '2011-2015', '2016-2020', '2021-2023']
labels = ['2000-2003','2004-2007', '2008-2011', '2012-2015', '2016-2019', '2020-2023']

# Create a new column 'year_group' by binning the 'year' column
unique_counts_all['year_group'] = pd.cut(unique_counts_all['year'], bins=bins, labels=labels, right=False)

# Group by 'year_group' and sum the 'year_count' for each group
unique_counts_all = unique_counts_all.groupby('year_group')['year_count'].sum().reset_index()

# Display the result
print(unique_counts_all)
unique_counts_all['year_group']
# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8', '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65', '#548569', '#474466', '#FDEBD0', '#F9EBB2', '#EAECEE', '#8B5A80']
# random.shuffle(darker_shades)

fig = px.bar(unique_counts_all, x='year_group', y='year_count', color='year_group', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('BarPlot_YearAll.html')
fig.show()
# Out:
#   year_group  year_count
# 0  2000-2003           6
# 1  2004-2007          10
# 2  2008-2011          33
# 3  2012-2015          47
# 4  2016-2019          42
# 5  2020-2023          30
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9c06d05-d5b7-4334-8f0f-a898f340b44b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9c06d05-d5b7-4334-8f0f-a898f340b44b")) {                    Plotly.newPlot(                        "d9c06d05-d5b7-4334-8f0f-a898f340b44b",                        [{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2000-2003","marker":{"color":"darkred","pattern":{"shape":""}},"name":"2000-2003","offsetgroup":"2000-2003","orientation":"v","showlegend":true,"textposition":"auto","x":["2000-2003"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2004-2007","marker":{"color":"lightblue","pattern":{"shape":""}},"name":"2004-2007","offsetgroup":"2004-2007","orientation":"v","showlegend":true,"textposition":"auto","x":["2004-2007"],"xaxis":"x","y":[10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2008-2011","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"2008-2011","offsetgroup":"2008-2011","orientation":"v","showlegend":true,"textposition":"auto","x":["2008-2011"],"xaxis":"x","y":[33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2012-2015","marker":{"color":"#FFABAB","pattern":{"shape":""}},"name":"2012-2015","offsetgroup":"2012-2015","orientation":"v","showlegend":true,"textposition":"auto","x":["2012-2015"],"xaxis":"x","y":[47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2016-2019","marker":{"color":"#91a8a8","pattern":{"shape":""}},"name":"2016-2019","offsetgroup":"2016-2019","orientation":"v","showlegend":true,"textposition":"auto","x":["2016-2019"],"xaxis":"x","y":[42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2020-2023","marker":{"color":"#95ab8a","pattern":{"shape":""}},"name":"2020-2023","offsetgroup":"2020-2023","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-2023"],"xaxis":"x","y":[30],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %%
sum(unique_counts_all['year_count'])
# Out:
# 168

# %% [markdown]
# ###Years - ReACT Driven

# %%
df = pd.read_excel("article.xlsx")
df = df[df['ReACTs'] != 'No ReACT could be derived from the article']
df = df.dropna(subset=['ReACTs'])
df = df[~df['ReACTs'].str.contains('Article excluded')]

unique_counts = df['Publication Year'].value_counts().reset_index()

unique_counts.columns = ['year', 'year_count']
unique_counts

# Define the bins for grouping the years
bins = [2000, 2004, 2008, 2012, 2016, 2020, 2024]

# Define labels for the groups
# labels = ['2001-2005', '2006-2010', '2011-2015', '2016-2020', '2021-2023']
labels = ['2000-2003','2004-2007', '2008-2011', '2012-2015', '2016-2019', '2020-2023']

# Create a new column 'year_group' by binning the 'year' column
unique_counts['year_group'] = pd.cut(unique_counts['year'], bins=bins, labels=labels, right=False)

# Group by 'year_group' and sum the 'year_count' for each group
unique_counts = unique_counts.groupby('year_group')['year_count'].sum().reset_index()

# Display the result
print(unique_counts)

unique_counts['year_group']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8', '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65', '#548569', '#474466', '#FDEBD0', '#F9EBB2', '#EAECEE', '#8B5A80']
# random.shuffle(darker_shades)

fig = px.bar(unique_counts, x='year_group', y='year_count', color='year_group', color_discrete_sequence=darker_shades)

# Save the plot as an HTML file
fig.write_html('BarPlot_YearReACTDriven.html')
fig.show()
# Out:
#   year_group  year_count
# 0  2000-2003           1
# 1  2004-2007           1
# 2  2008-2011           1
# 3  2012-2015           5
# 4  2016-2019          12
# 5  2020-2023           5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5514171-27db-406e-9d6f-373506f53542" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5514171-27db-406e-9d6f-373506f53542")) {                    Plotly.newPlot(                        "b5514171-27db-406e-9d6f-373506f53542",                        [{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2000-2003","marker":{"color":"darkred","pattern":{"shape":""}},"name":"2000-2003","offsetgroup":"2000-2003","orientation":"v","showlegend":true,"textposition":"auto","x":["2000-2003"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2004-2007","marker":{"color":"lightblue","pattern":{"shape":""}},"name":"2004-2007","offsetgroup":"2004-2007","orientation":"v","showlegend":true,"textposition":"auto","x":["2004-2007"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2008-2011","marker":{"color":"lightgreen","pattern":{"shape":""}},"name":"2008-2011","offsetgroup":"2008-2011","orientation":"v","showlegend":true,"textposition":"auto","x":["2008-2011"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2012-2015","marker":{"color":"#FFABAB","pattern":{"shape":""}},"name":"2012-2015","offsetgroup":"2012-2015","orientation":"v","showlegend":true,"textposition":"auto","x":["2012-2015"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2016-2019","marker":{"color":"#91a8a8","pattern":{"shape":""}},"name":"2016-2019","offsetgroup":"2016-2019","orientation":"v","showlegend":true,"textposition":"auto","x":["2016-2019"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year_group=%{x}\u003cbr\u003eyear_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2020-2023","marker":{"color":"#95ab8a","pattern":{"shape":""}},"name":"2020-2023","offsetgroup":"2020-2023","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-2023"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...

# %%
import plotly.graph_objects as go

colors = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8', '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65', '#548569', '#474466', '#FDEBD0', '#F9EBB2', '#EAECEE', '#8B5A80']
color_all = random.shuffle(colors)
color_react = random.shuffle(colors)

fig = go.Figure(data=[
    go.Bar(name='All analyzed articles', x=unique_counts_all['year_group'], y=unique_counts_all['year_count'], marker=dict(color=color_all)),
    go.Bar(name='ReACT driven articles', x=unique_counts['year_group'], y=unique_counts['year_count'], marker=dict(color=color_react))
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6660080b-112d-49fb-8703-486f35423ade" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6660080b-112d-49fb-8703-486f35423ade")) {                    Plotly.newPlot(                        "6660080b-112d-49fb-8703-486f35423ade",                        [{"name":"All analyzed articles","x":["2000-2003","2004-2007","2008-2011","2012-2015","2016-2019","2020-2023"],"y":[6,10,33,47,42,30],"type":"bar"},{"name":"ReACT driven articles","x":["2000-2003","2004-2007","2008-2011","2012-2015","2016-2019","2020-2023"],"y":[1,1,1,5,12,5],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ### Distribution of Articles - with respect to publication types
# ####  All articles

# %%
import random
df = pd.read_excel("article.xlsx")
df = df.dropna(subset=['Type'])

unique_counts_all = df['Type'].value_counts().reset_index()

# Rename the columns for clarity
unique_counts_all.columns = ['Publication Type', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']

random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.bar(unique_counts_all, x='Count', y='Publication Type', color='Publication Type', color_discrete_sequence=darker_shades, orientation='h')

# Save the plot as an HTML file
fig.write_html('BarPlot_PublicationTypeAll.html')

# fig.write_image("pub_type_analyzed.png")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c92f9c2b-98de-4719-a1fa-ad292da87f69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c92f9c2b-98de-4719-a1fa-ad292da87f69")) {                    Plotly.newPlot(                        "c92f9c2b-98de-4719-a1fa-ad292da87f69",                        [{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conference","marker":{"color":"#649E7D","pattern":{"shape":""}},"name":"Conference","offsetgroup":"Conference","orientation":"h","showlegend":true,"textposition":"auto","x":[101],"xaxis":"x","y":["Conference"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Journal","marker":{"color":"#D8D8D8","pattern":{"shape":""}},"name":"Journal","offsetgroup":"Journal","orientation":"h","showlegend":true,"textposition":"auto","x":[47],"xaxis":"x","y":["Journal"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grey Literature","marker":{"color":"#FAE5D3","pattern":{"shape":""}},"name":"Grey Literature","offsetgroup":"Grey Literature","orientation":"h","showlegend":true,"textposition":"auto","x":[14],"xaxis":"x","y":["Grey Literature"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Book","marker":{"color":"#6C5B7B","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Book"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Workshop","marker":{"color":"#7C83FD","pattern":{"shape":""}},"name":"Workshop","offsetgroup":"Workshop","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["Workshop"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Working Paper","marker":{"color":"#E47878","pattern":{"shape":""}},"name":"Working Paper","offsetgroup":"Working Paper","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Working Paper"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Interactive Poster","marker":{"color":"#BAC9FF","pattern":{"shape":""}},"name":"Interactive Poster","offsetgroup":"Interactive Poster","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Interactive Poster"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Preprint","marker":{"color":"#C0C999","pattern":{"shape":""}},"name":"Preprint","offsetgroup":"Preprint","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Preprint"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...

# %%
unique_counts_all['Count']
# Out:
# 0    101
# 1     47
# 2     14
# 3      2
# 4      2
# 5      1
# 6      1
# 7      1
# Name: Count, dtype: int64

# %% [markdown]
# ### Distribution of Articles - with respect to publication types
# ####  ReACT Driven articles

# %%
df = pd.read_excel("article.xlsx")
df = df[df['ReACTs'] != 'No ReACT could be derived from the article']
df = df.dropna(subset=['ReACTs'])
df = df[~df['ReACTs'].str.contains('Article excluded')]


df = df.dropna(subset=['Type'])

unique_counts = df['Type'].value_counts().reset_index()

# Rename the columns for clarity
unique_counts.columns = ['Publication Type', 'Count']

# Define an array of colors
darker_shades = ['darkred', 'lightblue', 'lightgreen', '#FFABAB', '#91a8a8',
                 '#95ab8a', '#00a86b', '#8E44AD', '#2E4053', '#D35400', '#a37b65',
                 '#6C5B7B', '#C0C999', '#7D8CC4', '#FFA07A', '#88D8B0',
    '#826c7F', '#D8D8D8', '#5F758E', '#E2B464', '#649E7D',
    '#CAAE77', '#7A9E9F', '#FAE5D3', '#BAC9FF', '#E47878',
    '#D2F2D2', '#7C83FD', '#F5A623', '#A77B7B', '#D8D8D8']

random.shuffle(darker_shades)

# Create an interactive bar plot using Plotly Express
fig = px.bar(unique_counts, x='Count', y='Publication Type', color='Publication Type', color_discrete_sequence=darker_shades, orientation='h')

# Save the plot as an HTML file
fig.write_html('BarPlot_PublicationTypeReACTDriven.html')
# fig.write_image("pub_type_react.png")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8b442b41-7dc1-4d83-92c6-f4d72fe481ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b442b41-7dc1-4d83-92c6-f4d72fe481ef")) {                    Plotly.newPlot(                        "8b442b41-7dc1-4d83-92c6-f4d72fe481ef",                        [{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Conference","marker":{"color":"#6C5B7B","pattern":{"shape":""}},"name":"Conference","offsetgroup":"Conference","orientation":"h","showlegend":true,"textposition":"auto","x":[18],"xaxis":"x","y":["Conference"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Publication Type=%{y}\u003cbr\u003eCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Journal","marker":{"color":"#E47878","pattern":{"shape":""}},"name":"Journal","offsetgroup":"Journal","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["Journal"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...

# %%
import plotly.graph_objects as go

# color_all = 'green'
# color_react = 'darkred'

fig = go.Figure(data=[
    go.Bar(name='All analyzed articles', x=unique_counts_all['Count'], y=unique_counts_all['Publication Type'], orientation='h'),
    go.Bar(name='ReACT driven articles', x=unique_counts['Count'], y=unique_counts['Publication Type'], orientation='h')
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb9b80e2-f5bd-46bb-9387-45a65554339c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb9b80e2-f5bd-46bb-9387-45a65554339c")) {                    Plotly.newPlot(                        "bb9b80e2-f5bd-46bb-9387-45a65554339c",                        [{"name":"All analyzed articles","orientation":"h","x":[101,47,14,2,2,1,1,1],"y":["Conference","Journal","Grey Literature","Book","Workshop","Working Paper","Interactive Poster","Preprint"],"type":"bar"},{"name":"ReACT driven articles","orientation":"h","x":[18,7],"y":["Conference","Journal"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar": ...
